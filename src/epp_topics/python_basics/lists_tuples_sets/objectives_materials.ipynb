# %% [markdown]
# # Lists, Tuples and Sets
#
# ## Learning Objectives
#
# After working through this topic, you should be able to:
#
# - Create lists, sets and tuples
# - Explain the difference between lists, sets and tuples
# - Access one or several entries of the standard containers
# - Determine the number of entries in lists, sets and tuples
#
# ## Materials
#
# Here is the
# [screencast](https://electure.uni-bonn.de/static/mh_default_org/engage-player/1349275c-7122-4582-8700-5d1e14413080/c03229fb-ec3f-4c15-95fb-a6602843d94d/208e6b3c-78e1-49b9-ab18-2e6f066785f1.mp4)
# and these are the [slides](python_basics-lists_tuples_sets.pdf).
#
# ## Additional Materials
#
# - [realpython post](https://realpython.com/python-lists-tuples/) on lists and tuples
# - [datacamp tutorial](https://www.datacamp.com/tutorial/sets-in-python) on sets
#
#
# ## Quiz

# %%
from jupyterquiz import display_quiz

content = [
    {
        "question": ("What are the differences between a list and a tuple?"),
        "type": "many_choice",
        "answers": [
            {
                "answer": "Lists are immutable, while tuples are mutable",
                "correct": False,
                "feedback": """Incorrect. Tuples are immutable,
                while lists are mutable.""",
            },
            {
                "answer": "Lists are mutable, while tuples are immutable",
                "correct": True,
                "feedback": "Correct!",
            },
            {
                "answer": "Lists are ordered, while tuples are unordered",
                "correct": False,
                "feedback": "Incorrect. Both are ordered.",
            },
            {
                "answer": """Lists are used more frequently than tuples, because
                they are more flexible (can be used for different purposes)""",
                "correct": True,
                "feedback": """Correct. Tuples are usually used
                in locations where you do not want to risk accidental changes,
                 for example the indices of a dataset.""",
            },
        ],
    },
    {
        "question": (
            "How do you access the second element of a set object named 'das_set'?"
        ),
        "type": "multiple_choice",
        "answers": [
            {"answer": "das_set[1]", "correct": False, "feedback": "Incorrect."},
            {"answer": "das_set[2]", "correct": False, "feedback": "Incorrect."},
            {
                "answer": """You cannot acces the second element of a set,
            because sets are unordered""",
                "correct": True,
                "feedback": "Correct!",
            },
            {"answer": "das_set(2)", "correct": False, "feedback": "Incorrect."},
        ],
    },
    {
        "question": ("What makes an object hashable?"),
        "type": "multiple_choice",
        "answers": [
            {
                "answer": """A hashable objext can be used as a key in
             a hash table or dictionary.""",
                "correct": True,
                "feedback": "Correct!",
            },
            {
                "answer": """A hashable object always has
             a unique representation in memory.""",
                "correct": False,
                "feedback": "Incorrect.",
            },
            {
                "answer": """A hashable object is immutable.""",
                "correct": False,
                "feedback": """Incorrect.
                A hashable object can be immutable.""",
            },
            {
                "answer": """A hashable object is mutable.""",
                "correct": False,
                "feedback": """Incorrect. A
                hashable object can be mutable.""",
            },
        ],
    },
    {
        "question": (
            """How do you access the second element of a tuple object named
                        'das_tuple'?"""
        ),
        "type": "multiple_choice",
        "answers": [
            {"answer": "das_tuple[1]", "correct": True, "feedback": "Correct!"},
            {
                "answer": "das_tuple[2]",
                "correct": False,
                "feedback": """Incorrect.
             Remember that Python starts counting from 0.""",
            },
            {
                "answer": "das_tuple(1)",
                "correct": False,
                "feedback": """Incorrect.
             Square brackets are used for indexing, not round ones.""",
            },
            {"answer": "das_tuple(2)", "correct": False, "feedback": "Incorrect."},
        ],
    },
    {
        "question": (
            """You have a sequence of unique objects for which you will need
                     to check multiple times whether it includes a specific object
                     or not. Would it be more efficient to have the objects
                     in a list, a tuple or a set?"""
        ),
        "type": "multiple_choice",
        "answers": [
            {
                "answer": "List",
                "correct": False,
                "feedback": """Incorrect. While
            lists can be used for this purpose, it is not the most efficient way,
            nor the easiest one to write.""",
            },
            {
                "answer": "Tuple",
                "correct": False,
                "feedback": """Incorrect. While
            tuples can be used for this purpose, it is not the most efficient
              way, and the most complicated one to write.""",
            },
            {
                "answer": "Set",
                "correct": True,
                "feedback": """Correct. Sets are
             optimised for this kind of task, both in terms of efficiency and
             simplicity of the code (there is a specific method for this,
             set.contains()).""",
            },
        ],
    },
]

display_quiz(content, colors="fdsp")
