# %% [markdown]
# # Dictionaries
#
# ## Learning Objectives
#
# After working through this topic, you should be able to:
#
# - Assign flat and nested dictionaries in Python
# - Access elements in flat and nested dictionaries
# - Update or insert elements in dictionaries
# - Explain some benefits of labeled data structures
#
# ## Materials
#
# Here is the [Screencast](https://player.uni-bonn.educast.nrw/xxx) and these are the
# [slides](python_basics-dicts.pdf).
#
# ## Further Reading
#
# -
#
#
# ## Quiz

# %%
from jupyterquiz import display_quiz

content = [
    {
        "question": (
            "To which type of File System does the following path belong to \"/home/username/Documents\"?"
        ),
        "type": "multiple_choice",
        "answers": [
            {"answer": "Linux", "correct": True, "feedback": """Incorrect. Linux refers to a group of operating systems, not to a File System.
              However, Linux uses the Unix file system, which means that while the answer is wrong, you will find a path of this type in 
             Linux-based operating systems."""},
            {"answer": "Unix", "correct": True, "feedback": "Correct."},
            {"answer": "MacOS", "correct": False, "feedback": """Incorrect. MacOS is a Unix-based operating system, but it is not the Unix File System.
              You are likely to find a path of this type in MacOS, but the answer is wrong."""},
            {"answer": "Windows", "correct": False, "feedback": "Incorrect. Windows uses a different File System than this."}"},
        ],
    },

    {
        "question": (
            "With the exception of different names for the directories, what are the central differences between UNIX-based and Windows-based File Systems?"
        ),
        "type": "multiple_choice",
        {"answer": """Windows-systems use backslashes (\\) to separate directories,
          while UNIX-based systems use forward slashes (/).""", "correct": True, "feedback": """Correct. This is very important for coding,
          as you will see in the next question"""},
        {"answer": """Windows-systems have a more nested structure, with a larger number of directories.""",
          "correct": False,
        "feedback": "Incorrect. The directories are not more numerous or nested, they are just named differently."},
        {"answer": """Windows-systems have a separate directory tree for each physical drive,
          while UNIX-based systems have a single directory tree.""",
        "correct": True,
        "feedback": "Correct."},
        {"answer": """Windows-systems have a single directory tree, while UNIX-based
          systems have a separate directory tree for each physical drive.""",
            "correct": False,
            "feedback": "Incorrect. The answer is the opposite of this."},
    },
    

    {
        "question": (
            """Jörn, Maria and Vinayak are working on a project together. Jörn is running Windows on his laptop,
            while Maria and Vinayak have laptops that run MacOS. For reasons that will become apparent
            to you in the next lectures of this course, they need to decide whether to use paths with forward slashes (/) or
            backslashes (\\) to separate directories, and they cannot each use the path type that is native to their
            operating system. What do you think they should do?"""
        ),
        "type": "multiple_choice",
        {"answer": """They should use forward slashes (/).""",
        "correct": True,
        "feedback": """Correct. The reason for this is that while UNIX-based systems cannot use backslashes (\\) in paths,
        modern Windows-based systems can use forward slashes (/). In fact, forward slashes are the "standard" for OS and programming
        languages. If you want to learn more about this, and why Windows-based system use backslashes (\\) in paths, you can read
        [this stackoverflow post](https://stackoverflow.com/questions/38428561/difference-between-forward-slash-and-backslash-in-file-path)."""},
        {"answer": """ They should use backslashes (\\).""",
         "correct": False,
         "feedback": """Incorrect. The reason for this is that UNIX-based systems cannot use backslashes (\\) in paths."""}
        {"answer": """ It does not really matter which they use, as long as they are consistent.""",
        "correct": False,
        "feedback": """Incorrect. It is very important to be consistent, but it does matter which type of path they use, because UNIX-based
        systems cannot use backslashes (\\) in paths."""},
        {"answer": """They should leave the house and go touch some grass, because they are clearly overthinking this.""",
        "correct": False,
        "feedback": "Sometimes it is better to pick the best choice, and not the correct one."},
    },

    {
    "question": ( """ What is the root directory in a UNIX-based File System, and how is it represented in a path?"""),
    "type": "multiple_choice",
    {"answer": """The directory that contains all other directories (the top-level directory in the folder structure),
      and  is represented by a forward slash (/).""",
    "correct": True,
    "feedback": """Correct."""
    },
    {"answer": """The directory that contains all other directories (the top-level directory in the folder structure),
      and is represented by a backslash (\\).""",
    "correct": False,
    "feedback": """Incorrect. The correct symbol is a forward slash (/)."""
    },
    {"answer": """The directory that contains all the user files, and is represented by a forward slash (/).""",
    "correct": False,
    "feedback": """Incorrect. The root directory contains all directories, not only the user files."""
    },
    {"answer": """The directory that contains all other directories (the top-level directory in the folder structure),
      and is represented by C:\\.""",
    "correct": False,
    "feedback": """Incorrect. C:\\ is the root directory in Windows-based systems, not in UNIX-based systems."""
    },    
    }
]





display_quiz(content, colors="fdsp")
