# %% [markdown]
# # Strings
#
# ## Learning Objectives
#
# After working through this topic, you should be able to:
#
# - Assign and manipulate string variables in Python
# - List a few common string manipulation methods
# - Use f-strings to piece different strings together
#
# ## Materials
#
# Here is the
# [screencast](https://electure.uni-bonn.de/static/mh_default_org/engage-player/73cf749a-3edf-4de2-8a11-94c9a65b7d08/63e944c6-06ce-471a-9718-d78eeb634f0f/31082a74-c9aa-4740-9c3c-81df7281a1f1.mp4)
# and these are the [slides](python_basics-strings.pdf).
#
# ## Additional Materials
#
# - [Documentation](https://docs.python.org/3/library/stdtypes.html#text-sequence-type-str) of Python built-in types
#
#
# ## Quiz

# %%
from jupyterquiz import display_quiz

content = [
    {
        "question": (
            "If you need to represent 'hello world', in Python you would use ..."
        ),
        "type": "multiple_choice",
        "answers": [
            {"answer": "A string", "correct": True, "feedback": "Correct."},
            {"answer": "A float", "correct": False, "feedback": "Incorrect."},
            {"answer": "An integer", "correct": False, "feedback": "Incorrect."},
            {"answer": "A Boolean", "correct": False, "feedback": "Incorrect."},
        ],
    },
    {
        "question": (
            "What do you expect the following code to return?str(True) + str(False)"
        ),
        "type": "multiple_choice",
        "answers": [
            {
                "answer": "1",
                "correct": False,
                "feedback": "This is the result of True + False.",
            },
            {"answer": "10", "correct": False, "feedback": "This is not a str."},
            {
                "answer": '"10"',
                "correct": False,
                "feedback": "This is the result of \
                str(int(True)) + str(int(False))",
            },
            {
                "answer": "None of the others",
                "correct": True,
                "feedback": "The code returns TrueFalse.",
            },
        ],
    },
    {
        "question": ("Which of the following is a string method?"),
        "type": "many_choice",
        "answers": [
            {
                "answer": "capitalize()",
                "correct": True,
                "feedback": "Converts the first character to upper case.",
            },
            {
                "answer": "endswith()",
                "correct": True,
                "feedback": "Returns true if the string ends with the specified value",
            },
            {
                "answer": "find()",
                "correct": True,
                "feedback": "Searches the string for a specified value and returns \
                the position of where it was found",
            },
            {
                "answer": "isbeta()",
                "correct": False,
                "feedback": "This is not a string method. \
                isalpha() Returns True if all characters \
                in the string are in the alphabet.",
            },
        ],
    },
    {
        "question": (
            "What do you expect the following code to return? (if it were two lines) "
            'course_name = "EPP" '
            'f"This is the {course_name} course."'
        ),
        "type": "multiple_choice",
        "answers": [
            {
                "answer": r"This is the \{course_name\} course",
                "correct": False,
                "feedback": "Incorrect.",
            },
            {
                "answer": "This is the EPP course",
                "correct": True,
                "feedback": "Correct.",
            },
            {
                "answer": "Error stating that addition among strings is done with +.",
                "correct": False,
                "feedback": "Incorrect.",
            },
            {
                "answer": "None of the others",
                "correct": False,
                "feedback": "Incorrect.",
            },
        ],
    },
]

display_quiz(content, colors="fdsp")
