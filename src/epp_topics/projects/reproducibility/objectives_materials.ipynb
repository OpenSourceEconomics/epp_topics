# %% [markdown]
# # What does reproducibility mean?
#
# ## Learning Objectives
#
# After working through this topic, you should be able to:
#
# - Discuss which materials need to be available for a project to be reproducible
# - Explain why using Version control (correctly) is essential to reproducibility
# - Construct example that show why automation is essential to reproducibility
#
# ## Materials
#
# Here is the
# [Screencast](https://player.uni-bonn.educast.nrw/4d9b8406-f929-4c92-aef8-7a9ebef4b128)
# and these are the [slides](projects-reproducibility.pdf).
#
# ## Additional materials
#
# [https://datacodestandard.org/](https://datacodestandard.org/)
#
#
# ## Quiz

# %%
content = [
    {
        "question": "In order for a project to be reproducible it needs to have:",
        "type": "many_choice",
        "answers": [
            {
                "answer": "the raw data",
                "correct": True,
                "feedback": "Correct.",
            },
            {
                "answer": "the source code",
                "correct": True,
                "feedback": "Correct.",
            },
            {
                "answer": "the programs needed to run the code",
                "correct": True,
                "feedback": "Correct.",
            },
            {
                "answer": "the results",
                "correct": False,
                "feedback": "Incorrect. The results can be generated from the \
                    raw data and the source code.",
            },
        ],
    },
    {
        "question": "Version control:",
        "type": "many_choice",
        "answers": [
            {
                "answer": "helps guaranteeing the integrity of the raw data",
                "correct": True,
                "feedback": "Correct. For example, raw data can be changed \
                    by mistake. Version control allows to go back to the \
                    previous version.",
            },
            {
                "answer": "enables the use of previous versions of the code",
                "correct": True,
                "feedback": "Correct.",
            },
            {
                "answer": "preserves the code in case local files are lost",
                "correct": False,
                "feedback": "Incorrect. This is not the main purpose of \
                    version control. Simple (simultaneous) online backups would \
                    do a better job. However, producing backups is a nice side \
                    effect of version control.",
            },
            {
                "answer": "often ends up consuming a lot of memory",
                "correct": False,
                "feedback": "Incorrect. Version control is very efficient in \
                    terms of memory usage. Additionally, only the source \
                    code and the raw data are under version control. \
                    This minimizes the memory usage.",
            },
        ],
    },
    {
        "question": "Maintaining output file under version control:",
        "type": "many_choice",
        "answers": [
            {
                "answer": "Is a good idea because it allows to track changes in the output.",
                "correct": False,
                "feedback": "Incorrect. If the comparison of different outputs is \
                    needed, then both outputs should be present in the final version.",
            },
            {
                "answer": "Is not a good idea because it would consume a lot of memory.",
                "correct": True,
                "feedback": "Correct.",
            },
            {
                "answer": "Is not a good idea because generated output can become outdated.",
                "correct": True,
                "feedback": "Correct. Having both the source code and the output \
                    under version control generate the risk of having inconsistencies \
                    between the two.",
            },
            {
                "answer": "Is is a good idea because it makes the project more reproducible.",
                "correct": False,
                "feedback": "Incorrect. Output file are reproduced \
                    from the raw data and the source code. ",
            },
        ],
    },
    {
        "question": "Organize a project with an outomated workflow:",
        "type": "many_choice",
        "answers": [
            {
                "answer": "Is essential for reproducibility.",
                "correct": True,
                "feedback": "Correct. The workflow should be automated to \
                    enable individuals external to the project to run it.",
            },
            {
                "answer": "Enables coworkers to easily join the project.",
                "correct": True,
                "feedback": "Correct. There is no need to explain the workflow \
                    to the new coworkers.",
            },
            {
                "answer": "Enables the future self to easily join the project.",
                "correct": True,
                "feedback": "Correct. While working on a project, it is easy to \
                    forget the details of the workflow. An automated workflow \
                    minimizes the risk of forgetting the details",
            },
            {
                "answer": "Could be substituted by a DAG that explains the \
                    relationship between files.",
                "correct": False,
                "feedback": "Incorrect. A DAG is a good way to visualize the \
                    workflow, but it does not replace the automated workflow itself. \
                    An automated worklow minimizes human errors and \
                    is much faster.",
            },
        ],
    },
]

from jupyterquiz import display_quiz

display_quiz(content, colors="fdsp")
