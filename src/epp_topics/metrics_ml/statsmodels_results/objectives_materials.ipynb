# %% [markdown]
# # Working with statsmodels' results objects
#
# ## Learning Objectives
#
# After working through this topic, you should be able to:
#
# - explain the difference between a model object and a regression results object
# - handle regression results objects
# - display the most important results as numbers on the screen
# - generate predicted values for observations and plot them along with the data points
#
# ## Materials
#
# Video:
#
# <iframe
#   src="https://electure.uni-bonn.de/paella7/ui/watch.html?id=8270cd55-772d-43b1-80d8-60b8a22d46a8"
#   width="640"
#   height="360"
#   frameborder="0"
#   allowfullscreen
# ></iframe>
#
# Download the [slides](metrics_ml-statsmodels_results.pdf).
#
# [statsmodels documentation for fitting models and summarising the results](https://www.statsmodels.org/stable/gettingstarted.html#model-fit-and-summary)
#
# <!-- ## Quiz -->

# %%
# content = [
#     {
#         "question": "Pandas ...",
#         "code": "import pandas as pd",
#         "type": "many_choice",
#         "answers": [
#             {
#                 "answer": (
#                     "aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa "
#                     "bbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbb",
#                 ),
#                 "correct": True,
#                 "feedback": "",
#             },
#             {
#                 "answer": (
#                     "aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa "
#                     "ccccc",
#                 ),
#                 "correct": False,
#                 "feedback": "",
#             },
#             {
#                 "answer": (
#                     "aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa "
#                     "ddddd",
#                 ),
#                 "correct": True,
#                 "feedback": "",
#             },
#             {
#                 "answer": (
#                     "aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa "
#                     "eeeeee",
#                 ),
#                 "correct": False,
#                 "feedback": "",
#             },
#         ],
#     },
# ]

# from jupyterquiz import display_quiz

# display_quiz(content, colors="fdsp")
