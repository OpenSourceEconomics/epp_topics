# %% [markdown]
# # Executing `.py` files in VS Code (conda/mamba)
#
# ```{warning}
# This page is about the **conda** / **mamba** package manager. Since 2025, we recommend
# using **pixi** instead, see the [updated chapter](python-installation-and-execution)
# ```
#
#
# ## Learning Objectives
#
# After working through this topic, you should be able to:
#
# - Select different python interpreters in VS Code
# - Run python files in VS Code
#
# ## Materials
#
# Video:
#
# <iframe
#   src="https://electure.uni-bonn.de/paella7/ui/watch.html?id=527c21d3-ef88-4e70-a62d-a2261436203f"
#   width="640"
#   height="360"
#   frameborder="0"
#   allowfullscreen
# ></iframe>
#
# Download the [slides](python_installation_execution_via_conda-executing_py_vscode.pdf).
