# %% [markdown]
# # Collections and Generics
#
# ## Learning Objectives
#
# After working through this topic, you should be able to:
#
# - Type lists, dicts, tuples, and sets with their element types
# - Understand the difference between concrete and abstract collection types
# - Use TypeVar to create generic functions that preserve types
# - Type callable objects (functions as arguments)
# - Understand how type narrowing works with isinstance checks
#
# ## Materials
#
# <iframe
#   src="https://example.com/placeholder"
#   width="640"
#   height="360"
#   frameborder="0"
#   allowfullscreen
# ></iframe>
#
# Download the [slides](type_hints-collections_generics.pdf).
#
# ## Quiz

# %%
from epp_topics.quiz_utilities import display_quiz

content = {
    "How do you annotate a list of integers in Python 3.9+?": {
        "list[int]": True,
        "List[int]": True,
        "list(int)": False,
        "int[]": False,
    },
    "How do you annotate a dictionary with string keys and float values?": {
        "dict[str, float]": True,
        "dict[str: float]": False,
        "dict{str, float}": False,
        "dictionary[str, float]": False,
    },
    "What is the difference between tuple[int, str] and tuple[int, ...]?": {
        "First is exactly two elements, second is any number of ints": True,
        "They are the same": False,
        "tuple[int, ...] is invalid syntax": False,
        "tuple[int, str] allows any number of ints and strs": False,
    },
    "When should you use Sequence instead of list in type hints?": {
        "When you only read from the collection and want flexibility": True,
        "Always, because it's more general": False,
        "When you need to modify the collection": False,
        "Never, always use list": False,
    },
}

display_quiz(content)
