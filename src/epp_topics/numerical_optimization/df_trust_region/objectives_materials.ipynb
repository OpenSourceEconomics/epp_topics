# %% [markdown]
# # Derivative-Free Trust Region
#
# ## Learning Objectives
#
# After working through this topic, you should be able to:
#
# - Explain the idea underlying the derivative-free trust region optimization algorithm
# - Discuss the advantages and disadvantages of using this algorithm
#
# ## Materials
#
# <iframe
#   src="https://electure.uni-bonn.de/paella7/ui/watch.html?id=6fce7d98-0351-468d-b751-9e60b15cc0cd"
#   width="640"
#   height="360"
#   frameborder="0"
#   allowfullscreen
# ></iframe>
#
# Here are the [slide(s)](numerical_optimization-df_trust_region.pdf).
#
# ## Quiz

# %%
content = {
    "What is the main idea behind derivative-free trust region algorithm?": {
        "Systematically exploring a predefined set of parameter values": False,
        "Randomly selecting parameter values within specified bounds": False,
        "Iteratively updating parameter values based on gradient descent": False,
        "Using heuristics to find the optimal parameter combination": False,
        "Employing trust regions to restrict parameter updates within \
            a localized region where a surrogate model based on \
            interpolation or regression approximates the \
            objective function": True,
    },
    'The derivative-based trust region algorithm could get "stuck" \
        in a region with a local minimum': {
        "True": True,
        "False": False,
    },
}

from epp_topics.quiz_utilities import display_quiz

display_quiz(content)
