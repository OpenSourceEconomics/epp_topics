# %% [markdown]
# # Writing Readme Files
#
# ## Learning Objectives
#
# After working through this topic, you should be able to:
#
# - explain why it is important to write a good `README.md` file
# - decide what to put in a `README.md` file for a specific project
#
# ## Materials
#
# Video:
#
# <iframe
#   src="https://electure.uni-bonn.de/paella7/ui/watch.html?id=3ee8f7f3-8487-45b1-8938-fadd7332766d"
#   width="640"
#   height="360"
#   frameborder="0"
#   allowfullscreen
# ></iframe>
#
# Download the [slides](texts-writing_readme_files.pdf).
#
# ## Quiz

# %%
content = [
    {
        "question": "Readme files should be written in ...",
        "type": "multiple_choice",
        "answers": [
            {
                "answer": "... plain text because it is universal.",
                "correct": False,
                "feedback": "Any text-based format is somewhat universal.",
            },
            {
                "answer": (
                    "... markdown because GitHub renders it nicely, so nobody ever "
                    "needs to read the source."
                ),
                "correct": False,
                "feedback": "We definitely want to read the source, too!",
            },
            {
                "answer": (
                    "... markdown because it is readable in source form and can be "
                    "rendered nicely in many different forms."
                ),
                "correct": True,
                "feedback": "Precisely!",
            },
            {
                "answer": (
                    "... ReStructuredText because it is the more powerful than the "
                    "other options."
                ),
                "correct": False,
                "feedback": "We don't need that power for a Readme file.",
            },
        ],
    },
    {
        "question": "Readme files should contain the following information.",
        "type": "many_choice",
        "answers": [
            {
                "answer": "How to run the project.",
                "correct": True,
                "feedback": "Most definitely.",
            },
            {
                "answer": (
                    "The assumptions made about the system for the project to run."
                ),
                "correct": True,
                "feedback": "This may save others huge amounts of time.",
            },
            {
                "answer": "The basic purpose of the project.",
                "correct": True,
                "feedback": "How should one know whether continue looking otherwise?",
            },
            {
                "answer": "A detailed description of the public-facing functions.",
                "correct": False,
                "feedback": "In very rare cases, this might be helpful. But typically, "
                "this will be part of a dedicated documentation.",
            },
            {
                "answer": (
                    "A dependency tree with all nodes and tasks of the project."
                ),
                "correct": False,
                "feedback": "Even for trivial projects, this would quickly become too "
                "large.",
            },
        ],
    },
]

from jupyterquiz import display_quiz

display_quiz(content, colors="fdsp")
