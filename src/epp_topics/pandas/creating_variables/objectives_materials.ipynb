# %% [markdown]
# # Creating variables
#
# ## Learning Objectives
#
# After working through this topic, you should be able to:
#
# - Assign new columns to a DataFrame
# - Explain why loops over columns are harmless and loops over rows have to be avoided
# - Use vectorized calculations between numeric columns
# - Use vectorized string methods
# - Combine information from two columns based on conditions
# - Replace values in variables
#
# ## Materials
#
# Here is the
# [Screencast](https://player.uni-bonn.educast.nrw/cc0eced6-56fc-4719-ba6c-00d9d486e9ae)
# and these are the [slides](pandas-creating_variables.pdf).
#
# ## Further Reading
#
#
#
# ## Quiz

# %%
content = [
    {
        "question": "Pandas ...",
        "code": "import pandas as pd",
        "type": "many_choice",
        "answers": [
            {
                "answer": (
                    "aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa "
                    "bbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbb"
                ),
                "correct": True,
                "feedback": "",
            },
            {
                "answer": (
                    "aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa "
                    "ccccc"
                ),
                "correct": False,
                "feedback": "",
            },
            {
                "answer": (
                    "aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa "
                    "ddddd"
                ),
                "correct": True,
                "feedback": "",
            },
            {
                "answer": (
                    "aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa "
                    "eeeeee"
                ),
                "correct": False,
                "feedback": "",
            },
        ],
    },
]

from jupyterquiz import display_quiz

display_quiz(content, colors="fdsp")
