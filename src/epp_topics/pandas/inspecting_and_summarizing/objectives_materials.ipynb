# %% [markdown]
# # Inspecting and summarizing data
#
# ## Learning Objectives
#
# After working through this topic, you should be able to:
#
# - Summarize datasets
# - Look at unique values and value_counts of data
# - Visualize the distribution of variables
# - Calculate summary statistics
#
# ## Materials
#
# Here is the
# [Screencast](https://player.uni-bonn.educast.nrw/c1284f96-a00c-4117-a12a-832040f34dd7)
# and these are the [slides](pandas-inspecting_and_summarizing.pdf).
#
# <!--
# ## Further Reading
#  -->
#
#
# ## Quiz

# %%
content = [
    {
        "question": (
            "The describe method of a dataset \
            returns:"
        ),
        "type": "multiple_choice",
        "answers": [
            {
                "answer": "A table",
                "correct": False,
                "feedback": "Tables are not python objects.",
            },
            {
                "answer": "A DataFrame",
                "correct": True,
                "feedback": "Correct.",
            },
            {
                "answer": "A dictionary",
                "correct": False,
                "feedback": "Incorrect.",
            },
            {
                "answer": """An Array""",
                "correct": False,
                "feedback": "Incorrect.",
            },
        ],
    },
    {
        "question": (
            "The describe method of a dataset \
            reports:"
        ),
        "type": "many_choice",
        "answers": [
            {
                "answer": "The count of missing values",
                "correct": False,
                "feedback": "This information is not explicitly \
                    reported.",
            },
            {
                "answer": "The count of non-missing values",
                "correct": True,
                "feedback": "Correct.",
            },
            {
                "answer": "The median",
                "correct": True,
                "feedback": "Correct. This is indexed with 50%.",
            },
            {
                "answer": "The max",
                "correct": True,
                "feedback": "Correct.",
            },
        ],
    },
    {
        "question": ("The plot method can be applied to:"),
        "type": "multiple_choice",
        "answers": [
            {
                "answer": "Only to clean data",
                "correct": False,
                "feedback": "Plots of clean data provide useful information.\
                    Graphs that goes in papers should be based on clean data.\
                    However, inspecting raw data can be very helpful.",
            },
            {
                "answer": "Any Series",
                "correct": True,
                "feedback": "Correct.",
            },
            {
                "answer": "Only summary statistics",
                "correct": False,
                "feedback": "Summary statistics of a single variable are rarely \
                    plotted.\
                    Summary statistics can be plotted to compare them \
                        across different variables.",
            },
            {
                "answer": "Only monotone series",
                "correct": False,
                "feedback": 'Monotone series might have "nicer" graphs. \
                    However, the plot method can be applied also to \
                        non-monotone series.',
            },
        ],
    },
    {
        "question": ("Scatterplots are useful for:"),
        "type": "multiple_choice",
        "answers": [
            {
                "answer": "Clearly present the data points",
                "correct": False,
                "feedback": "Often scatterplots are not the best choice \
                    to present data points\
                    In large datasets, it is impossible to distinguish \
                        different observations.",
            },
            {
                "answer": "Identify outliers",
                "correct": True,
                "feedback": "The intercative plot can be used to eyeball \
                    outliers in \
                    small and middle sized datasets.",
            },
            {
                "answer": "Get an idea of the summary statistics",
                "correct": False,
                "feedback": "It's very hard to infer summary statistics\
                    from a scatterplot.",
            },
            {
                "answer": "Scatterplots are not very useful",
                "correct": False,
                "feedback": "Incorrect.",
            },
        ],
    },
    {
        "question": (
            'Suppose you are handling a dataset you are not familiar\
                with and that \
                    it does not come with a description of hte variables.\
                    The dataset has the variable "group". \
                    The easiest way to discover how many goups are there \
                        is to:'
        ),
        "type": "multiple_choice",
        "answers": [
            {
                "answer": "Open the dataset in data viewer,\
                     sort the data by the group variable and scroll down",
                "correct": False,
                "feedback": "This procedure is error prone.",
            },
            {
                "answer": "Convert the variable in a set and check the \
                    length of the set",
                "correct": False,
                "feedback": "This works but it is a bit cumbersome.",
            },
            {
                "answer": "Use the unique method",
                "correct": True,
                "feedback": "Correct. This approach also identifies \
                    misspelled groups.",
            },
            {
                "answer": "Use the value_counts method",
                "correct": False,
                "feedback": "This method reports the unique values, \
                    but these are not easily accesible.",
            },
        ],
    },
]

from jupyterquiz import display_quiz

display_quiz(content, colors="fdsp")
