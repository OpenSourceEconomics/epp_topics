# %% [markdown]
# # Loading and saving data
#
# ## Learning Objectives
#
# After working through this topic, you should be able to:
#
# - List different data formats you can load into pandas
# - Choose suitable formats for your own datasets
# - Configure the reading functions to use modern datatypes
# - Read the pandas documentation to learn about advanced options for reading data
#
# ## Materials
#
# Here is the
# [Screencast](https://player.uni-bonn.educast.nrw/f191b5fe-0626-43b4-8b42-e0b97e036b9f)
# and these are the [slides](pandas-loading_and_saving.pdf).
#
# ## Additional Materials
#
#
#
# ## Quiz

# %%
content = [
    {
        "question": "Storing data in csv format is useful because",
        "type": "many_choice",
        "answers": [
            {
                "answer": "you can open the data in a text editor.",
                "correct": True,
                "feedback": "About the only reason and pointless for large datasets.",
            },
            {
                "answer": "actually, it is not useful at all in general.",
                "correct": True,
                "feedback": "Indeed!",
            },
            {
                "answer": "it is easy to preserve categorical data types.",
                "correct": False,
                "feedback": "This is not easy at all.",
            },
            {
                "answer": "csv is a clearly defined standard.",
                "correct": False,
                "feedback": "Very much to the contrary.",
            },
        ],
    },
]

from jupyterquiz import display_quiz

display_quiz(content, colors="fdsp")

# %%
content = [
    {
        "name": "intro",
        "front": ("Describe the format you would use for each of the following tasks."),
        "back": (
            "Let's go through them step by step (click on next in the bottom right)."
        ),
    },
    {
        "name": "share_with_stata",
        "front": "Share data with a Stata user.",
        "back": (
            "Use Stata's dta format. It is typically better to solve compatibility "
            "issues on the Python side."
        ),
    },
    {
        "name": "share_with_R",
        "front": "Share data with a user of R.",
        "back": (
            "Use Apache Arrow's feather format. It can easily be read into R and it"
            "is a very well-defined standard."
        ),
    },
    {
        "name": "re_use_in_workflow",
        "front": "Read in the data downstream in the project.",
        "back": (
            "Pickle the data. You are guaranteed to get the same thing back since "
            "you will be using the same versions of Python and Pandas."
        ),
    },
    {
        "name": "share_with_python",
        "front": "Share data with a user of Python.",
        "back": (
            "Use Apache Arrow's feather format. It can easily be read into Python and "
            "it is a very well-defined standard. Alternatively, pickle is also likely "
            "to work, although there can be incompatibilities across versions of "
            "Python and it is easy to include objects in a pickle file that require "
            "the same import statements to work."
        ),
    },
]


from jupytercards import display_flashcards

display_flashcards(content)
