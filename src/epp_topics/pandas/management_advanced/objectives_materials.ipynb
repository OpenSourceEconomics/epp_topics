# %% [markdown]
# # Data management: Tips, tricks, and advanced topics
#
#
# ## Learning Objectives
#
# After working through this topic, you should be able to:
#
# - Explain at which point in the data processing pipeline you want to select the sample
#   for analysis (e.g., imposing restrictions on observations being used)
# - Use metadata programmatically to avoid repetitive code when cleaning many similar
#   variables
# - Combine variables from different data sources into a single variable
# - Apply strategies for handling variables that change their coding over time in a panel
#   dataset
#
#
# ## Materials
#
# Video:
#
# <iframe
#   src="https://electure.uni-bonn.de/paella7/ui/watch.html?id=df721dcf-0e95-4df7-82ea-67ba1fda2dfe"
#   width="640"
#   height="360"
#   frameborder="0"
#   allowfullscreen
# ></iframe>
#
# Download the [slides](pandas-management_advanced.pdf).
#
#
# ## Quiz

# %%
from epp_topics.quiz_utilities import display_quiz

content = {
    "When should you select the sample for analysis (e.g., dropping observations with"
    " missing covariates)?": {
        "At the very beginning of the data management pipeline": False,
        "At the end of the data management pipeline": True,
        "In the middle of cleaning each variable": False,
        "During the analysis stage": False,
    },
    "What are the benefits of using metadata programmatically in data cleaning?": {
        "It allows you to avoid repetitive code when cleaning many similar"
        " variables": True,
        "It makes the data file smaller": False,
        "It automatically fixes all data quality issues": False,
        "It replaces the need for functions": False,
    },
    "You have a DataFrame with metadata where 'nlsy_name' is the index and"
    " 'readable_name' is a column. You want to clean all variables starting with"
    " 'anxiety_'. What is the best approach?": {
        "Use a loop over metadata to find all relevant variables and clean them"
        " programmatically": True,
        "Write separate code for each anxiety variable": False,
        "Copy and paste the cleaning code for each variable": False,
        "Manually rename all variables before cleaning": False,
    },
    "You have information about transfer receipts from two different sources in the"
    "SOEP data (person-level and calendar data). According to the slides, how should"
    " you handle this?": {
        "Create three variables: one for each source and one combined variable obtained"
        " by a function": True,
        "Only keep the variable from the more reliable source": False,
        "Merge both sources into a single variable and discard the original"
        " information": False,
        "Keep only one source to avoid redundancy": False,
    },
    "What are the two strategies for handling variables that change their coding over"
    " time?": {
        "One time series variable with a single harmonizing cleaning function": True,
        "Keep differently-named variables for each time point, then combine them": True,
        "Always use the most recent coding and ignore historical data": False,
        "Drop all variables that changed over time": False,
    },
    "When applying upfront restrictions (e.g., age limits) that you will not change in"
    " robustness checks, when should you impose them?": {
        "At the very beginning or end of the data management pipeline": True,
        "Right after loading the raw data": True,
        "In the middle of data cleaning": False,
        "During the analysis stage": False,
    },
}

display_quiz(content)
