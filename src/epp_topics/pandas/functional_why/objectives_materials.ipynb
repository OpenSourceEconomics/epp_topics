# %% [markdown]
# # Functional data cleaning: The Why
#
# ## Learning Objectives
#
# Our fundamental rules for data cleaning are:
#
# 1. Start with an empty DataFrame
#
# 1. Touch every variable just once
#
# 1. Touch with a pure function
#
# After working through this topic, you should be able to explain how these rules help
# achieve the following five goals:
#
# 1. Code must be readable at different levels of abstraction
#
# 2. Pipeline always starts from the original data, which is never modified
#
# 3. Must be able to find out quickly what a variable contains
#
# 4. There must not be state in any column's contents
#
# 5. Data management and analysis should be separated
#
# ## Materials
#
# Video:
# <iframe
#   src="https://electure.uni-bonn.de/paella7/ui/watch.html?id=77447c52-f897-49df-95e1-b3a9897c7694"
#   width="640"
#   height="360"
#   frameborder="0"
#   allowfullscreen
# ></iframe>
#
# Download the [slides](pandas-functional_why.pdf).
#
# ## Quiz

# %%
from epp_topics.quiz_utilities import display_quiz

content = {
    "After performing some data management operations on a DataFrame, the best practice"
    " is to save the DataFrame to ...": {
        "a new file with a new name, so that the original data is not lost": True,
        "the same file, so that the original data is overwritten": False,
        "a new file with the same name, so that the original data is not lost": False,
    },
    "Why is it good practice to separate data management operations from data"
    " analysis?": {
        "It allows for easier tracking and debugging of errors.": True,
        "It makes it easier to test the results of the data management"
        " operations.": True,
        "It makes the code faster.": False,
    },
    "The main purpose of using functions in data cleaning is to": {
        "Save typing": False,
        "Make your code more readable by showing its high-level structure": True,
        "Make your code more efficient": False,
        "Demonstrate your programming skills": False,
        "Easily re-use code in several places of your project": True,
    },
    "What are the disadvantages of the functional approach to data management?": {
        "It is less readable for non-programmers": False,
        "It is less efficient": False,
        "It uses more memory": False,
        "It does not work for all projects": False,
        "It is painful to implement in Stata": True,
    },
    "Why are good function names better than comments?": {
        "They are easier to write": False,
        "They are less likely to become outdated over time": True,
        "They will be more visible in Tracebacks": True,
        "You are more likely to actually read them": True,
    },
    "What problem does 'touching every variable just once' help solve?": {
        "It makes it easier to quickly find out what a variable contains": True,
        "It makes the code run faster": False,
        "It reduces memory usage": False,
        "It prevents variable name conflicts": False,
    },
    "Why is it important to avoid 'state' in column contents?": {
        "If a variable is modified in multiple places, debugging becomes much"
        " harder": True,
        "It makes the data file larger": False,
        "It prevents using pandas functions": False,
        "It slows down the code": False,
    },
}

display_quiz(content)
