# %% [markdown]
# # From Stringly-Typed to Strongly-Typed
#
# ## Learning Objectives
#
# After working through this topic, you should be able to:
#
# - Identify stringly-typed code and understand its problems
# - Convert dict-based configuration to typed dataclasses
# - Replace string options with Enum or Literal types
# - Design typed APIs with good migration strategies
# - Apply the "generous input, strict output" principle
#
# ## Materials
#
# <iframe
#   src="https://example.com/placeholder"
#   width="640"
#   height="360"
#   frameborder="0"
#   allowfullscreen
# ></iframe>
#
# Download the [slides](software_engineering-type_hints_stringly.pdf).
#
# ## Quiz

# %%
from epp_topics.quiz_utilities import display_quiz

content = {
    "What are problems with stringly-typed code?": {
        "Typos in strings are only discovered at runtime": True,
        "No IDE autocomplete for valid options": True,
        "Code runs slower": False,
        "Difficult to discover what options exist": True,
    },
    "How did optimagic improve algorithm selection?": {
        "From algorithm='scipy_lbfgsb' to algorithm=om.algorithms.scipy_lbfgsb": True,
        "By removing algorithm options entirely": False,
        "By using integers instead of strings": False,
        "IDE can now autocomplete available algorithms": True,
    },
    "What is the 'generous input, strict output' principle?": {
        "Accept both old (string) and new (typed) inputs during migration": True,
        "Always return strings for flexibility": False,
        "Return typed results even when accepting flexible inputs": True,
        "Only accept typed inputs, never strings": False,
    },
    "How should you replace a config dict with string keys?": {
        "Create a frozen dataclass with typed fields": True,
        "Use a list of tuples instead": False,
        "Replace string keys with integer indices": False,
        "Use Enum or Literal for fixed option values": True,
    },
}

display_quiz(content)
