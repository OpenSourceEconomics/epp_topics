# %% [markdown]
# # Testing code that should raise errors
#
# ## Learning Objectives
#
# After working through this topic, you should be able to:
#
# - use tests to pin down desired behaviour of your functions
# - use pytest to check that expected errors are raised
# - explain why it is important to check that tests pass for the reasons that match your mental model of the code
#
# ## Materials
#
# Here is the
# [Screencast](https://electure.uni-bonn.de/static/mh_default_org/engage-player/78fdf25a-17a6-4fe3-a926-85047627a562/5b18bd8b-131a-4133-abd9-1a5da6b9a019/6b67f76d-02c1-432c-868b-ac8d42106661.mp4)
# and these are the [slides](software_engineering-pytest_error_handling.pdf).
#
#
# ## Quiz

# %%
content = [
    {
        "question": "Why is it important to test code that should raise errors?",
        "type": "multiple_choice",
        "answers": [
            {
                "answer": "To make the code more complex.",
                "correct": False,
                "feedback": "Testing code that should raise errors \
                    is not about making the code more complex but about \
                    ensuring that it behaves as expected in error scenarios.",
            },
            {
                "answer": "To impress colleagues with advanced testing techniques.",
                "correct": False,
                "feedback": "The primary purpose of testing code \
                    that should raise errors is to ensure that error \
                    conditions are handled correctly, not to impress colleagues.",
            },
            {
                "answer": "To verify that the code handles error \
                    conditions appropriately.",
                "correct": True,
                "feedback": "Correct! Testing code that should raise errors is \
                    essential to verify that error conditions are handled  \
                    appropriately and do not lead to unexpected behavior.",
            },
            {
                "answer": "To skip error handling and proceed with code execution.",
                "correct": False,
                "feedback": "Testing code that should raise errors is about \
                    ensuring proper error handling, not skipping it.",
            },
        ],
    },
    {
        "question": "It is important that tests pass for \
            the resons we expect because:",
        "type": "multiple_choice",
        "answers": [
            {
                "answer": "If the test passes but unexpected behaviors occur, \
                    the analyses could be unreliable.",
                "correct": True,
                "feedback": "Correct.",
            },
            {
                "answer": "Otherwise other functions might fail.",
                "correct": False,
                "feedback": "Incorrect. This is not a primary concern.",
            },
            {
                "answer": "The ta will deduct you points from the assignment.",
                "correct": False,
                "feedback": "Incorrect. The code you write is for you.",
            },
            {
                "answer": "Otherwise it will be very hard to find \
                    what the error is.",
                "correct": True,
                "feedback": "Correct.",
            },
        ],
    },
    {
        "question": "What is the purpose of the `pytest.raises` \
            block in a test case for code that should raise errors?",
        "type": "multiple_choice",
        "answers": [
            {
                "answer": "To ensure that no errors are raised during testing.",
                "correct": False,
                "feedback": "The `pytest.raises` block is specifically \
                    used to check that expected errors are raised during testing.",
            },
            {
                "answer": "To terminate the program if an error is encountered.",
                "correct": False,
                "feedback": "The `pytest.raises` block does not terminate the program;\
                    it checks if the expected error is raised.",
            },
            {
                "answer": "To check that expected errors are raised during testing.",
                "correct": True,
                "feedback": "Correct! The `pytest.raises` block is used to \
                    ensure that the specified error is raised during testing.",
            },
            {
                "answer": "To print diagnostic information about the program's errors.",
                "correct": False,
                "feedback": "The primary purpose of `pytest.raises` is not \
                    to print diagnostic information but to check for expected errors.",
            },
        ],
    },
]

from jupyterquiz import display_quiz

display_quiz(content, colors="fdsp")
