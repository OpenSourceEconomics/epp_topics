# %% [markdown]
# # Subchapter Title
#
# ## Learning Objectives
#
# After working through this topic, you should be able to:
#
# - ...
# - ...
#
# ## Materials
#
# Here is [Screencast](https://player.uni-bonn.educast.nrw/xxx). These are the
# [slides](git-committing_diffing.pdf).
#
# ## Further Reading
#
# XXX

# %%
from jupyterquiz import display_quiz

content = [
    {
        "question": (
            """ You just finished editing multiple files in a repository
            managed by Git. What do you have to run on your terminal
            to update the remote repository? """
        ),
        "type": "multiple_choice",
        "answers": [
            {
                "answer": """git stash, git pull, git stash pop""",
                "correct": False,
                "feedback": """Incorrect!""",
            },
            {
                "answer": """git add ., git commit -m "Some comment",
                git push""",
                "correct": True,
                "feedback": """Correct!""",
            },
            {
                "answer": """git commit, git push""",
                "correct": False,
                "feedback": """Incorrect!""",
            },
            {
                "answer": """git pull, git push""",
                "correct": False,
                "feedback": """Incorrect!""",
            },
        ],
    },
    {
        "question": ("git add ..."),
        "type": "multiple_choice",
        "answers": [
            {
                "answer": """adds a file in the current directory to
                the staging area""",
                "correct": True,
                "feedback": """Correct! Basically, it selects the files
                you want to commit.""",
            },
            {
                "answer": """creates a new node in the DAG representing
                  the revision history.""",
                "correct": False,
                "feedback": """Incorrect! """,
            },
            {
                "answer": """uploads the local commits made since the
                last synchronisation with the central repository.""",
                "correct": False,
                "feedback": """Incorrect! """,
            },
            {
                "answer": """downloads the latest version of the
                repository from the central repository.""",
                "correct": False,
                "feedback": """Incorrect! """,
            },
        ],
    },
    {
        "question": ("git commit ..."),
        "type": "multiple_choice",
        "answers": [
            {
                "answer": """creates a new node in the DAG representing
                  the revision history.""",
                "correct": True,
                "feedback": """Correct! """,
            },
            {
                "answer": """adds a file in the current directory to
                the staging area""",
                "correct": False,
                "feedback": """Incorrect! """,
            },
            {
                "answer": """uploads the local commits made since the
                last synchronisation with the central repository.""",
                "correct": False,
                "feedback": """Incorrect! """,
            },
            {
                "answer": """downloads the latest version of the
                repository from the central repository.""",
                "correct": False,
                "feedback": """Incorrect! """,
            },
        ],
    },
    {
        "question": ("git pull ..."),
        "type": "multiple_choice",
        "answers": [
            {
                "answer": """downloads any changes made to the central
                repository since the last synchronisation.""",
                "correct": True,
                "feedback": """Correct! """,
            },
            {
                "answer": """creates a new node in the DAG representing
                  the revision history.""",
                "correct": False,
                "feedback": """Incorrect! """,
            },
            {
                "answer": """adds a file in the current directory to
                the staging area""",
                "correct": False,
                "feedback": """Incorrect! """,
            },
            {
                "answer": """uploads the local commits made since the
                last synchronisation with the central repository.""",
                "correct": False,
                "feedback": """Incorrect! """,
            },
        ],
    },
    {
        "question": ("git status is used to ..."),
        "type": "multiple_choice",
        "answers": [
            {
                "answer": """check the status of the working directory
                and the staging area.""",
                "correct": True,
                "feedback": """Correct! The status includes information
                about the files that have been modified, added or deleted.""",
            },
            {
                "answer": """check the changes made to the remote repository
                since the last synchronisation.""",
                "correct": False,
                "feedback": """Incorrect! """,
            },
            {
                "answer": """check how many commits have been made.""",
                "correct": False,
                "feedback": """Incorrect! """,
            },
            {
                "answer": """check the status of the remote repository.""",
                "correct": False,
                "feedback": """Incorrect! """,
            },
        ],
    },
    {
        "question": (
            """What will happen if you execute the following command:
        git checkout 1234567890"""
        ),
        "type": "multiple_choice",
        "answers": [
            {
                "answer": """You will exit the current git repository.""",
                "correct": False,
                "feedback": """Incorrect! """,
            },
            {
                "answer": """You will create a new branch named 1234567890.""",
                "correct": False,
                "feedback": """Incorrect! """,
            },
            {
                "answer": """You will update files in your local repository
                to match files in the branch 1234567890.""",
                "correct": True,
                "feedback": """Correct! """,
            },
            {
                "answer": """You will create a new commit with the hash 1234567890.""",
                "correct": False,
                "feedback": """Incorrect! """,
            },
        ],
    },
    {
        "question": ("""What is a tracked file in Git?"""),
        "type": "multiple_choice",
        "answers": [
            {
                "answer": """A file that has been added to the staging area.""",
                "correct": True,
                "feedback": """Correct! Tracked files are (also) files that have
                been added to the staging area.""",
            },
            {
                "answer": """A file that has been added to the repository.""",
                "correct": True,
                "feedback": """Correct! Tracked files are (also) files that were
                in the last snapshot.""",
            },
            {
                "answer": """A file that has been modified.""",
                "correct": False,
                "feedback": """Incorrect! """,
            },
            {
                "answer": """A file that has been deleted.""",
                "correct": False,
                "feedback": """Incorrect! """,
            },
        ],
    },
    {
        "question": ("""Why are good commit messages important?"""),
        "type": "many_choice",
        "answers": [
            {
                "answer": """They help you remember what you did.""",
                "correct": True,
                "feedback": """Correct! """,
            },
            {
                "answer": """They help your collaborators understand what you did.""",
                "correct": True,
                "feedback": """Correct! """,
            },
            {
                "answer": """They help you find a specific commit.""",
                "correct": True,
                "feedback": """Correct! """,
            },
            {
                "answer": """They help you relive all the good memories you made
                while programming.""",
                "correct": False,
                "feedback": """Incorrect! No good memories were made.""",
            },
        ],
    },
]

display_quiz(content)
